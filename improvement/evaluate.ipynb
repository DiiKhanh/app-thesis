# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.path.dirname('experiment/2304-01'), '..', '..','..')))
from helper_code import load_predictions_from_csv
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
def evaluate_model(model_name,folder, filename): 
    all_results = load_predictions_from_csv(folder, filename)
    y_pred = list()
    y_true = list()
    for res in all_results:
        y_pred.append(res['outcome_binary'])
        y_true.append(res['actual_outcome'])
    
    report = classification_report(y_true, y_pred, target_names=['Lớp 0 (Good)', 'Lớp 1 (Poor)'], digits=4)
    print(f"\nBảng đánh giá mô hình {model_name}:\n")
    print(report)
    
    
    cm = confusion_matrix(y_true, y_pred)
    
    plt.figure(figsize=(5,4))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['Dự đoán Good', 'Dự đoán Poor'], yticklabels=['Thật Good', 'Thật Poor'])
    plt.ylabel('Thực tế')
    plt.xlabel('Dự đoán')
    plt.title(f'Confusion Matrix {model_name}')
    plt.show()

# %%
folder = "results"
filename = "densenet121-002.csv"
evaluate_model("DenseNet121", folder, filename)
# Out:
# Bảng đánh giá mô hình DenseNet121:
#
#               precision    recall  f1-score   support
#
# Lớp 0 (Good)     0.6471    0.7857    0.7097        42
# Lớp 1 (Poor)     0.8732    0.7750    0.8212        80
#
#     accuracy                         0.7787       122
#    macro avg     0.7601    0.7804    0.7654       122
# weighted avg     0.7954    0.7787    0.7828       122

# %%
folder = "results"
filename = "convnext-002.csv"
evaluate_model("ConvNext", folder, filename)
# Out:
# Bảng đánh giá mô hình ConvNext:
#
#               precision    recall  f1-score   support
#
# Lớp 0 (Good)     0.6522    0.7143    0.6818        42
# Lớp 1 (Poor)     0.8421    0.8000    0.8205        80
#
#     accuracy                         0.7705       122
#    macro avg     0.7471    0.7571    0.7512       122
# weighted avg     0.7767    0.7705    0.7728       122

# %%
folder = "results"
filename = "efficientnet-002.csv"
evaluate_model("EfficientNetV2", folder, filename)
# Out:
# Bảng đánh giá mô hình EfficientNetV2:
#
#               precision    recall  f1-score   support
#
# Lớp 0 (Good)     0.5714    0.8571    0.6857        42
# Lớp 1 (Poor)     0.8983    0.6625    0.7626        80
#
#     accuracy                         0.7295       122
#    macro avg     0.7349    0.7598    0.7242       122
# weighted avg     0.7858    0.7295    0.7361       122

# %%
folder = "results"
filename = "resnet50-002.csv"
evaluate_model("ResNet-50", folder, filename)
# Out:
# Bảng đánh giá mô hình ResNet-50:
#
#               precision    recall  f1-score   support
#
# Lớp 0 (Good)     0.5397    0.8095    0.6476        42
# Lớp 1 (Poor)     0.8644    0.6375    0.7338        80
#
#     accuracy                         0.6967       122
#    macro avg     0.7020    0.7235    0.6907       122
# weighted avg     0.7526    0.6967    0.7041       122
